# %%
pip install pycountry-convert
# Out:
# Requirement already satisfied: pycountry-convert in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (0.7.2)
# Requirement already satisfied: pprintpp>=0.3.0 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (0.4.0)
# Requirement already satisfied: pycountry>=16.11.27.1 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (24.6.1)
# Requirement already satisfied: pytest>=3.4.0 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (8.3.4)
# Requirement already satisfied: pytest-mock>=1.6.3 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (3.14.0)
# Requirement already satisfied: pytest-cov>=2.5.1 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (6.0.0)
# Requirement already satisfied: repoze.lru>=0.7 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (0.7)
# Requirement already satisfied: wheel>=0.30.0 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pycountry-convert) (0.45.1)
# Requirement already satisfied: colorama in c:\users\yirsu\appdata\roaming\python\python313\site-packages (from pytest>=3.4.0->pycountry-convert) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pytest>=3.4.0->pycountry-convert) (2.0.0)
# Requirement already satisfied: packaging in c:\users\yirsu\appdata\roaming\python\python313\site-packages (from pytest>=3.4.0->pycountry-convert) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from pytest>=3.4.0->pycountry-convert) (1.5.0)
# Requirement already satisfied: coverage>=7.5 in c:\users\yirsu\appdata\local\programs\python\python313\lib\site-packages (from coverage[toml]>=7.5->pytest-cov>=2.5.1->pycountry-convert) (7.6.12)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pycountry_convert as pc

def get_continent(country_name):
    """
    Given a country name, return the corresponding continent name.
    If the country cannot be converted, return "Unknown".
    """
    try:
        # Convert country name to its alpha-2 country code
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        # Get the continent code from the country code
        continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        # Convert continent code to continent name (e.g., 'Europe', 'Asia')
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except Exception:
        return "Unknown"

# Replace 'world_happiness.csv' with your CSV file path
input_csv = "World Happiness Report.csv"
df = pd.read_csv(input_csv)

# Create a new 'Continent' column by applying the get_continent function to each country name
df["Continent"] = df["Country"].apply(get_continent)

# Save the updated DataFrame to a new CSV file
output_csv = "world_happiness_with_continent.csv"
df.to_csv(output_csv, index=False)

print(f"Successfully created '{output_csv}' with the Continent column.")
# Out:
# Successfully created 'world_happiness_with_continent.csv' with the Continent column.
