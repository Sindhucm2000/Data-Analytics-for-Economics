# %%
pip install pycountry-convert
# Out:
# Collecting pycountry-convert
#   Downloading pycountry_convert-0.7.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting pprintpp>=0.3.0 (from pycountry-convert)
#   Downloading pprintpp-0.4.0-py2.py3-none-any.whl.metadata (7.9 kB)
# Collecting pycountry>=16.11.27.1 (from pycountry-convert)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting pytest>=3.4.0 (from pycountry-convert)
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-mock>=1.6.3 (from pycountry-convert)
#   Downloading pytest_mock-3.14.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting pytest-cov>=2.5.1 (from pycountry-convert)
#   Downloading pytest_cov-6.1.1-py3-none-any.whl.metadata (28 kB)
# Collecting repoze.lru>=0.7 (from pycountry-convert)
#   Downloading repoze.lru-0.7-py3-none-any.whl.metadata (1.1 kB)
# Collecting wheel>=0.30.0 (from pycountry-convert)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: colorama in c:\users\sindh\appdata\roaming\python\python313\site-packages (from pytest>=3.4.0->pycountry-convert) (0.4.6)
# Collecting iniconfig (from pytest>=3.4.0->pycountry-convert)
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: packaging in c:\users\sindh\appdata\roaming\python\python313\site-packages (from pytest>=3.4.0->pycountry-convert) (24.2)
# Collecting pluggy<2,>=1.5 (from pytest>=3.4.0->pycountry-convert)
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting coverage>=7.5 (from coverage[toml]>=7.5->pytest-cov>=2.5.1->pycountry-convert)
#   Downloading coverage-7.8.0-cp313-cp313-win_amd64.whl.metadata (8.7 kB)
# Downloading pycountry_convert-0.7.2-py3-none-any.whl (13 kB)
# Downloading pprintpp-0.4.0-py2.py3-none-any.whl (16 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.3 MB 4.9 MB/s eta 0:00:02
#    --------- ------------------------------ 1.6/6.3 MB 5.3 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.3 MB 5.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.3 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.7/6.3 MB 5.1 MB/s eta 0:00:01
#    ------------------------------- -------- 5.0/6.3 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 4.6 MB/s eta 0:00:00
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading pytest_cov-6.1.1-py3-none-any.whl (23 kB)
# Downloading pytest_mock-3.14.0-py3-none-any.whl (9.9 kB)
# Downloading repoze.lru-0.7-py3-none-any.whl (10 kB)
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading coverage-7.8.0-cp313-cp313-win_amd64.whl (214 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Installing collected packages: repoze.lru, pprintpp, wheel, pycountry, pluggy, iniconfig, coverage, pytest, pytest-mock, pytest-cov, pycountry-convert
# Successfully installed coverage-7.8.0 iniconfig-2.1.0 pluggy-1.5.0 pprintpp-0.4.0 pycountry-24.6.1 pycountry-convert-0.7.2 pytest-8.3.5 pytest-cov-6.1.1 pytest-mock-3.14.0 repoze.lru-0.7 wheel-0.45.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import pycountry_convert as pc

def get_continent(country_name):
    """
    Given a country name, return the corresponding continent name.
    If the country cannot be converted, return "Unknown".
    """
    try:
        # Convert country name to its alpha-2 country code
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        # Get the continent code from the country code
        continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        # Convert continent code to continent name (e.g., 'Europe', 'Asia')
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except Exception:
        return "Unknown"

# Replace 'world_happiness.csv' with your CSV file path
input_csv = "World Happiness Report.csv"
df = pd.read_csv(input_csv)

# Create a new 'Continent' column by applying the get_continent function to each country name
df["Continent"] = df["Country"].apply(get_continent)

# Save the updated DataFrame to a new CSV file
output_csv = "world_happiness_with_continent.csv"
df.to_csv(output_csv, index=False)

print(f"Successfully created '{output_csv}' with the Continent column.")
# Out:
# Successfully created 'world_happiness_with_continent.csv' with the Continent column.
